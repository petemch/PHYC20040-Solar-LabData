plt.ylabel('Offset in Jupiter Diameters')
plt.plot(TimeOfObsGan, DataGan, 'r+')

# %%
plt.title('Callisto measured offset in Jupiter Diameters')
plt.xlabel('Julian date')
plt.ylabel('Offset in Jupiter Diameters')
plt.plot(TimeOfObs, DataCal, 'r+')

# %%
def f(x,T0,A,P):
    return A*np.sin(2*np.pi*(x-T0)/P)

curve_fit(f, TimeOfObs, DataCal)
# Out:
# (array([0.5244545 , 0.70765588, 1.00000012]),
#  array([[ 9.99808932e+02, -5.17326986e+02, -4.02806101e-04],
#         [-5.17326986e+02,  2.71216617e+02,  2.08470870e-04],
#         [-4.02806101e-04,  2.08470870e-04,  1.62311813e-10]]))

# %%
curve_fit(f, TimeOfObsGan, DataGan)
# Out:
# (array([ 1.39597072, -0.89144316,  0.99999976]),
#  array([[ 6.27725677e+02,  3.92612827e+02, -2.56625967e-04],
#         [ 3.92612827e+02,  2.46511412e+02, -1.60517514e-04],
#         [-2.56625967e-04, -1.60517514e-04,  1.04919132e-10]]))

# %%
curve_fit(f, TimeOfObsEuropa, DataEuropa)
# Out:
# (array([-1.73578315,  0.40445959,  1.00000103]),
#  array([[ 2.33521302e+03, -6.83632359e+02, -9.68969510e-04],
#         [-6.83632359e+02,  2.00564839e+02,  2.83674991e-04],
#         [-9.68969510e-04,  2.83674991e-04,  4.02074508e-10]]))

# %%
curve_fit(f, TimeOfObsIo, DataIo)
# Out:
# (array([0.25692856, 0.41567918, 1.00000017]),
#  array([[ 3.85909862e+01, -1.24059934e+01, -1.73320198e-05],
#         [-1.24059934e+01,  4.16314695e+00,  5.57516917e-06],
#         [-1.73320198e-05,  5.57516917e-06,  7.78857608e-12]]))

# %%
def Mjup(A,P):
    return ((A/1050)**3)/((P/365)**2)
Mjup(0.41567918, 1.00000017)
# Out:
# 8.265944825176697e-06

# %%
#mass from Europa data
Mjup(0.40445959,  1.00000103)
# Out:
# 7.61451679460869e-06

# %%
#mass from Ganymede data
Mjup(-0.89144316,  0.99999976)
# Out:
# -8.152653999973485e-05

# %%
#Mass from Io data
Mjup(0.41567918, 1.00000017)
# Out:
# 8.265944825176697e-06

# %%
#mass from Callisto data
Mjup(0.70765588, 1.00000012)
# Out:
# 4.0783461740706934e-05

# %%
Mmean = ((4.0783461740706934e-05)+(8.152653999973485e-05)+(7.61451679460869e-06)+(7.61451679460869e-06))/4
print(Mmean)
# Out:
# 3.454761584005679e-05

# %%
#standard error
(1/3)*((4.0783461740706934e-05 - 3.454761584005679e-05)**2 +(8.152653999973485e-05 - 3.454761584005679e-05)**2 +(7.61451679460869e-06 - 3.454761584005679e-05)**2 +(7.61451679460869e-06 - 3.454761584005679e-05)**2)
# Out:
# 1.232229579227091e-09

# %%
#taking uncertainty as standard error over root of N
U = 1.232229579227091e-09/2
print(U)
# Out:
# 6.161147896135454e-10
